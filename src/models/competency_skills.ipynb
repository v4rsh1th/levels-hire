# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from tabulate import tabulate

# %%
# Load the dataset
dataset = pd.read_csv('../../data/processed/processed_data.csv')  # Replace 'your_dataset.csv' with the actual file path

# %%
# Create custom labels based on keywords in job titles
keywords_to_labels = {
    'analyst': 'Analyst',
    'manager': 'Manager',
    'developer': 'Developer',
    'engineer': 'Engineer',
    'scientist': 'Scientist',
    'architect': 'Architect',
    'consultant': 'Consultant',
    'specialist': 'Specialist',
    'administrator': 'Administrator',
    'manager': 'Manager',
}

# %%
# Function to assign labels based on keywords
def assign_label(job_title):
    for keyword, label in keywords_to_labels.items():
        if keyword in job_title.lower():
            return label
    return 'Other'

# %%
# Apply the function to create a 'Label' column
dataset['Label'] = dataset['Job Role Title'].apply(assign_label)

# Concatenate 'Job Role Title' and 'Skills Required' columns
dataset['Combined Text'] = dataset['Job Role Title'] + ' ' + dataset['Skills Required'].apply(lambda x: ', '.join(x))

# %%
# Print unique values in the 'Label' column
print("Unique Labels:", dataset['Label'].unique())
# Out:
# Unique Labels: ['Engineer' 'Scientist' 'Architect' 'Analyst' 'Developer' 'Manager'
#  'Specialist' 'Administrator' 'Consultant' 'Other']

# %%
# Create a mapping of skills to competency levels (you can define your own scale)
skill_to_competency = {
    'python': 'Advanced',
    'sql': 'Intermediate',
    'machine learning': 'Intermediate',
    'data visualization': 'Intermediate',
    'big data': 'Advanced',
    'hadoop': 'Advanced',
    'spark': 'Advanced',
    'java': 'Intermediate',
    'c++': 'Intermediate',
    'r': 'Intermediate',
    'aws': 'Intermediate',
    'azure': 'Intermediate',
    'tableau': 'Intermediate',
    'power bi': 'Intermediate',
    'tensorflow': 'Intermediate',
    'keras': 'Intermediate',
    'scikit learn': 'Intermediate',
    'nlp': 'Intermediate',
    'deep learning': 'Intermediate',
    'neural networks': 'Intermediate',
    'computer vision': 'Intermediate',
    'data mining': 'Intermediate',
    'data warehousing': 'Intermediate',
    'data modeling': 'Intermediate',
    'data engineering': 'Intermediate',
    'data architecture': 'Intermediate',
    'data governance': 'Intermediate',
    'data quality': 'Intermediate',
    'data analytics': 'Intermediate',
    'data science': 'Intermediate',
    'data analysis': 'Intermediate',
    'data management': 'Intermediate',
    'data integration': 'Intermediate',
    'data migration': 'Intermediate',
    'data strategy': 'Intermediate',
    
}

# %%
dataset['python'] = dataset['Job Role Title'].map(skill_to_competency)
dataset['sql'] = dataset['Job Role Title'].map(skill_to_competency)

# %%
# Map skills to competency levels in the dataset
for skill, competency in skill_to_competency.items():
    dataset[skill] = dataset['Skills Required'].apply(lambda skills: competency if skill.lower() in ' '.join(skills).lower() else None)

# %%
# # Drop rows with missing competency information
# dataset = dataset.dropna(subset=list(skill_to_competency.keys()))

# %%
# Print skills associated with the 'Analyst' job family
analyst_skills = dataset[dataset['Label'] == 'Analyst']['Skills Required']
print("\nSkills for Analysts:", analyst_skills)
# Out:
# Skills for Analysts: 4      SQL,  Excel,  Data Visualization,  Statistics,...
# 9      SQL,  Tableau,  Power BI,  Data Visualization,...
# 17     SQL,  Excel,  Tableau,  Data Visualization,  D...
# 19     Hadoop,  Spark,  Python,  SQL,  Data Visualiza...
# 27     SQL,  Excel,  Tableau,  Power BI,  Data Visual...
# 32     SQL,  Excel,  Data Visualization,  Statistical...
# 34     Data Analysis,  Hadoop,  Spark,  Python,  SQL,...
# 43     SQL,  Excel,  Data Visualization,  Statistical...
# 55     Data Governance,  Data Management,  Data Quali...
# 70     Data Analysis,  Hadoop,  Spark,  Python,  SQL,...
# 73     Data Quality Assurance,  Data Validation,  Dat...
# 84     Hadoop Performance,  Spark Performance,  Optim...
# 91     Data Analysis,  Hadoop,  Spark,  Python,  SQL,...
# 95     Data Governance,  Data Management,  Data Quali...
# 108    Hadoop Performance,  Spark Performance,  Optim...
# 112    Data Analysis,  Hadoop,  Spark,  Python,  SQL,...
# 117    SQL,  Excel,  Data Visualization,  Statistical...
# 119    Data Analysis,  Hadoop,  Spark,  Python,  SQL,...
# 128    SQL,  Excel,  Data Visualization,  Statistical...
# 138    SQL,  Excel,  Data Visualization,  Statistical...
# 140    Data Analysis,  Hadoop,  Spark,  Python,  SQL,...
# 149    SQL,  Excel,  Data Visualization,  Statistical...
# 157    Data Analysis,  SQL,  Excel,  Data Visualizati...
# 165    Business Intelligence,  Data Analysis,  Data V...
# 166    Data Testing,  Quality Assurance,  Hadoop,  Sp...
# 168    Data Analysis,  SQL,  Data Visualization,  Sta...
# 172    Cybersecurity,  Network Security,  Security In...
# Name: Skills Required, dtype: object

# %%
# TF-IDF vectorization on the concatenated text
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(dataset['Combined Text'])

# %%
# K-Means clustering
num_clusters = len(keywords_to_labels)
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(tfidf_matrix)
dataset['Cluster'] = kmeans.labels_
# Out:
# /Users/v4rsh1th/Downloads/projects/recruitment-analysis/venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# PCA for dimensionality reduction to 3D
pca = PCA(n_components=3)
pca_result = pca.fit_transform(tfidf_matrix.toarray())
dataset[['PCA1', 'PCA2', 'PCA3']] = pca_result

# %%
# Print all unique labels and their associated skills in a well-structured table
for label in dataset['Label'].unique():
    skills_for_label = ', '.join(dataset[dataset['Label'] == label]['Skills Required'])
    print(f"\nSkills for {label}s:")
    print(tabulate({'Skills': [skills_for_label]}, headers='keys', tablefmt='pretty'))
# Out:
# Skills for Engineers:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Skills                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Hadoop,  Spark,  SQL,  Python,  ETL,  Big Data,  NoSQL, Python,  TensorFlow,  PyTorch,  Machine Learning,  Deep Learning,  NLP,  Data Visualization, SQL,  ETL,  Data Modeling,  Data Warehousing,  Business Intelligence,  Dimensional Modeling, Hadoop,  Spark,  Python,  ETL,  NoSQL,  SQL, Hadoop,  Spark,  Scala,  Kafka,  Data Streaming,  NoSQL, Machine Learning,  Deep Learning,  Python,  TensorFlow,  PyTorch,  NLP, Hadoop,  Spark,  Python,  ETL,  Data Warehousing,  SQL, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive, SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure,  GCP, Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Data Preprocessing,  Model Evaluation, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  GCP,  Data Warehousing,  Python, SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, MLOps,  Model Deployment,  Docker,  Kubernetes,  Python,  MLflow,  CI/CD,  Monitoring, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Model Deployment, Hadoop,  Spark,  Docker,  Kubernetes,  CI/CD,  Jenkins,  Ansible,  Linux,  Scripting,  Infrastructure as Code, Hadoop,  Spark,  Troubleshooting,  Support,  Linux,  Shell Scripting,  Apache HBase,  Kafka, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, MLOps,  Model Deployment,  Docker,  Kubernetes,  Python,  MLflow,  CI/CD,  Monitoring, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Model Deployment,  Research, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration,  Leadership, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration,  Strategic Planning, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Model Deployment,  Research,  Leadership, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive, SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure, Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Data Preprocessing, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive, SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure, Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Data Preprocessing, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration, Cybersecurity,  Network Security,  Security Protocols,  SIEM Tools,  Firewall Management,  Intrusion Detection,  Security Policies, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Skills for Scientists:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Skills                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Python,  R,  Machine Learning,  Statistical Analysis,  Data Visualization,  SQL,  Big Data, Machine Learning,  Deep Learning,  Natural Language Processing,  Reinforcement Learning,  Python,  TensorFlow,  PyTorch, Python,  Machine Learning,  Data Visualization,  Statistical Analysis,  Big Data,  R, Python,  R,  Machine Learning,  Deep Learning,  Natural Language Processing,  Data Visualization, Python,  R,  Machine Learning,  Statistical Analysis,  Data Visualization,  Big Data, Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  TensorFlow,  Pandas,  Numpy, Machine Learning,  Deep Learning,  Neural Networks,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning Research,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis,  NLP, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Deep Learning,  Neural Networks,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Deep Learning,  Neural Networks,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  Deep Learning, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Skills for Architects:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Skills                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Hadoop,  Spark,  Data Modeling,  NoSQL,  Cloud Computing,  ETL, Hadoop,  Spark,  Data Modeling,  Cloud Computing,  NoSQL,  ETL,  Architecture Design, Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  NoSQL,  Cloud Computing,  Big Data Technologies,  Data Governance, Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  Solution Design,  AWS,  Azure, Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  Azure, Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  Cloud Data Warehouses,  Snowflake,  Redshift, Infrastructure Design,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  Scalability,  High Availability, Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  Cloud Data Warehouses,  Snowflake, Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  GCP, Infrastructure Design,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  Scalability,  High Availability, Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  Cloud Data Warehouses,  Snowflake,  Redshift, Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  NoSQL,  Cloud Computing,  Big Data Technologies,  Data Governance, Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  Azure, Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  NoSQL,  Cloud Computing,  Big Data Technologies,  Data Governance, Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  Azure, Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  NoSQL,  Cloud Computing,  Big Data Technologies,  Data Governance, Data Architecture,  Cloud Computing,  Data Warehousing,  SQL,  ETL,  Big Data Technologies,  Data Modeling,  Solution Design |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Skills for Analysts:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Skills                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# ...
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Hadoop,  Spark,  Linux,  HDFS,  Cloudera,  Hortonworks,  AWS, Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  HBase,  Kafka,  Linux,  Shell Scripting, Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  Linux,  Shell Scripting,  Cluster Management, Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  HBase,  Kafka,  Linux,  Shell Scripting, Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  HBase,  Kafka,  Linux,  Shell Scripting, Database Administration,  SQL,  Data Modeling,  Backup and Recovery,  Performance Tuning,  Database Security,  Troubleshooting, Database Security,  SQL,  Security Protocols,  Access Control,  Vulnerability Assessment,  Security Policies,  Encryption, Hadoop Administration,  Cluster Management,  Scalability,  Performance Optimization,  Cloud Computing,  Linux |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Skills for Consultants:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                                                                                                                                                                     Skills                                                                                                                                                                                                                                                                                                                                      |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Hadoop,  Spark,  SQL,  NoSQL,  Data Modeling,  Cloud Computing,  ETL, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  Azure,  Data Warehousing,  Python, Data Strategy,  Machine Learning,  Data Analytics,  Data Visualization,  SQL,  Python, Data Strategy,  Machine Learning,  Data Analytics,  Data Visualization,  SQL,  Python,  Client Engagement, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  Azure,  Data Warehousing,  Python, Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  Azure,  Data Warehousing,  Python, Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Data Strategy |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Skills for Others:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Skills                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  Machine Learning,  SQL,  Data Cleaning, Machine Learning,  Python,  TensorFlow,  PyTorch,  Data Preprocessing,  Model Evaluation,  Data Analysis, Machine Learning,  Deep Learning,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis, Data Analysis,  Data Visualization,  Excel,  Tableau,  SQL,  Python, Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Team Leadership, Data Compliance,  Data Privacy,  GDPR,  CCPA,  Data Governance,  Legal Compliance,  Risk Assessment, Ethical AI,  Responsible AI,  Fairness,  Bias Mitigation,  Ethical Guidelines,  AI Ethics, Machine Learning,  Data Analysis,  Python,  R,  Teaching,  Curriculum Development,  Data Visualization, Machine Learning Research,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis,  NLP, Machine Learning,  Deep Learning,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis, Machine Learning,  Data Analysis,  Python,  R,  Teaching,  Curriculum Development,  Data Visualization, MLOps,  Model Deployment,  CI/CD,  Monitoring,  Team Leadership,  Docker,  Kubernetes,  Python,  Strategy, Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Strategic Planning, Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  Machine Learning,  SQL,  Data Cleaning, Machine Learning,  Python,  TensorFlow,  PyTorch,  Data Preprocessing,  Model Evaluation,  Data Analysis, Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  Machine Learning,  SQL,  Data Cleaning, Machine Learning,  Python,  TensorFlow,  PyTorch,  Data Preprocessing,  Model Evaluation,  Data Analysis, Data Testing,  Quality Assurance,  Hadoop,  Spark,  SQL,  ETL,  Big Data Technologies,  Test Automation,  Data Validation, Machine Learning,  Deep Learning,  Neural Networks,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# Print unique values in the 'Skills Required' column
print("Unique Skills:", dataset['Skills Required'].unique())

print('-' * 100)
# Print unique values in the 'Label' column
print("Unique Labels:", dataset['Label'].unique())
# Out:
# Unique Skills: ['Hadoop,  Spark,  SQL,  Python,  ETL,  Big Data,  NoSQL'
#  'Python,  TensorFlow,  PyTorch,  Machine Learning,  Deep Learning,  NLP,  Data Visualization'
#  'Python,  R,  Machine Learning,  Statistical Analysis,  Data Visualization,  SQL,  Big Data'
#  'Hadoop,  Spark,  Data Modeling,  NoSQL,  Cloud Computing,  ETL'
#  'SQL,  Excel,  Data Visualization,  Statistics,  Data Cleaning,  Tableau,  Power BI'
#  'Hadoop,  Spark,  Java,  Python,  Kafka,  Hive,  Pig,  Flume'
#  'Machine Learning,  Deep Learning,  Natural Language Processing,  Reinforcement Learning,  Python,  TensorFlow,  PyTorch'
#  'ETL,  Data Quality,  Data Governance,  SQL,  Leadership,  Data Integration'
#  'SQL,  ETL,  Data Modeling,  Data Warehousing,  Business Intelligence,  Dimensional Modeling'
#  'SQL,  Tableau,  Power BI,  Data Visualization,  Business Analysis,  Data Reporting'
#  'Python,  Machine Learning,  Data Visualization,  Statistical Analysis,  Big Data,  R'
#  'Hadoop,  Spark,  Python,  ETL,  NoSQL,  SQL'
#  'Python,  TensorFlow,  PyTorch,  Deep Learning,  Computer Vision,  Natural Language Processing'
#  'Hadoop,  Spark,  Linux,  HDFS,  Cloudera,  Hortonworks,  AWS'
#  'Machine Learning,  Data Strategy,  Leadership,  Python,  R,  Data Analytics,  Data Visualization'
#  'Hadoop,  Spark,  Scala,  Kafka,  Data Streaming,  NoSQL'
#  'Hadoop,  Spark,  SQL,  NoSQL,  Data Modeling,  Cloud Computing,  ETL'
#  'SQL,  Excel,  Tableau,  Data Visualization,  Data Cleaning,  Data Analysis'
#  'Python,  R,  Machine Learning,  Deep Learning,  Natural Language Processing,  Data Visualization'
#  'Hadoop,  Spark,  Python,  SQL,  Data Visualization,  ETL'
#  'Machine Learning,  Deep Learning,  Python,  TensorFlow,  PyTorch,  NLP'
#  'Data Governance,  Data Quality,  Data Management,  Compliance,  Policy Development'
#  'Hadoop,  Spark,  Data Modeling,  Cloud Computing,  NoSQL,  ETL,  Architecture Design'
#  'Hadoop,  Spark,  Python,  ETL,  Data Warehousing,  SQL'
#  'Python,  TensorFlow,  PyTorch,  Deep Learning,  Leadership,  Project Management'
#  'Python,  R,  Machine Learning,  Statistical Analysis,  Data Visualization,  Big Data'
#  'Hadoop,  Spark,  Project Management,  Agile,  Scrum,  Stakeholder Communication'
#  'SQL,  Excel,  Tableau,  Power BI,  Data Visualization,  Data Cleaning'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  TensorFlow,  Pandas,  Numpy'
#  'SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure,  GCP'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Data Preprocessing,  Model Evaluation'
#  'SQL,  Excel,  Data Visualization,  Statistical Analysis,  Python,  R,  Tableau,  Power BI,  Data Cleaning'
#  'Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  NoSQL,  Cloud Computing,  Big Data Technologies,  Data Governance'
#  'Data Analysis,  Hadoop,  Spark,  Python,  SQL,  Data Visualization,  Data Cleaning,  Statistical Analysis'
#  'Machine Learning,  Deep Learning,  Neural Networks,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis'
#  'Data Strategy,  Team Leadership,  Project Management,  Data Analytics,  Data Visualization,  Machine Learning,  SQL,  Python'
#  'Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  Solution Design,  AWS,  Azure'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning'
#  'SQL,  Data Modeling,  ETL,  Data Integration,  Database Design,  Data Warehousing,  SQL Server,  Oracle,  Teradata'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration'
#  'Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  Machine Learning,  SQL,  Data Cleaning'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  Azure,  Data Warehousing,  Python'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Data Preprocessing,  Model Evaluation,  Data Analysis'
#  'Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  HBase,  Kafka,  Linux,  Shell Scripting'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  Deep Learning'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  GCP,  Data Warehousing,  Python'
#  'Machine Learning,  Deep Learning,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis'
#  'SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  Computer Vision,  NLP,  Data Preprocessing'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  SQL'
#  'Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  Azure'
#  'Data Strategy,  Machine Learning,  Data Analytics,  Data Visualization,  SQL,  Python'
#  'Hadoop Administration,  Cluster Management,  Scalability,  Performance Optimization,  Cloud Computing'
#  'MLOps,  Model Deployment,  Docker,  Kubernetes,  Python,  MLflow,  CI/CD,  Monitoring'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  Data Modeling,  AWS,  GCP'
#  'Data Analysis,  Data Visualization,  Excel,  Tableau,  SQL,  Python'
#  'Machine Learning Research,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis,  NLP'
#  'Project Management,  Data Strategy,  Data Analytics,  Team Leadership,  Data Visualization'
#  'Hadoop Security,  Apache Ranger,  Knox,  Kerberos,  Encryption,  Data Access Control'
#  'Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  Cloud Data Warehouses,  Snowflake,  Redshift'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Model Deployment'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Team Leadership'
#  'Hadoop,  Spark,  Docker,  Kubernetes,  CI/CD,  Jenkins,  Ansible,  Linux,  Scripting,  Infrastructure as Code'
#  'Data Quality Assurance,  Data Validation,  Data Cleansing,  SQL,  Data Profiling,  Data Governance'
#  'MLOps,  Model Deployment,  CI/CD,  Monitoring,  Team Leadership,  Docker,  Kubernetes,  Python'
#  'Data Compliance,  Data Privacy,  GDPR,  CCPA,  Data Governance,  Legal Compliance,  Risk Assessment'
#  'Ethical AI,  Responsible AI,  Fairness,  Bias Mitigation,  Ethical Guidelines,  AI Ethics'
#  'Infrastructure Design,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  Scalability,  High Availability'
#  'Machine Learning,  Data Analysis,  Python,  R,  Teaching,  Curriculum Development,  Data Visualization'
#  'Data Migration,  ETL,  Data Transformation,  Legacy Systems,  AWS,  Azure,  Data Cleansing'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance'
#  'Hadoop,  Spark,  Troubleshooting,  Support,  Linux,  Shell Scripting,  Apache HBase,  Kafka'
#  'Data Strategy,  Machine Learning,  Data Analytics,  Data Visualization,  SQL,  Python,  Client Engagement'
#  'Hadoop Performance,  Spark Performance,  Optimization,  Monitoring,  Troubleshooting,  Benchmarking'
#  'Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  Cloud Data Warehouses,  Snowflake'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Model Deployment,  Research'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Leadership'
#  'Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  Linux,  Shell Scripting,  Cluster Management'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  SQL,  Compliance'
#  'Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  GCP'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration,  Leadership'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Leadership'
#  'Data Migration,  ETL,  Data Transformation,  Legacy Systems,  AWS,  Azure,  Data Cleansing,  Leadership'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration,  Strategic Planning'
#  'MLOps,  Model Deployment,  CI/CD,  Monitoring,  Team Leadership,  Docker,  Kubernetes,  Python,  Strategy'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Strategic Planning'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Model Deployment,  Research,  Leadership'
#  'Data Analysis,  Hadoop,  Spark,  Python,  SQL,  Data Visualization,  Data Cleaning,  Statistical Analysis,  Leadership'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Data Preprocessing'
#  'Data Testing,  Quality Assurance,  Hadoop,  Spark,  SQL,  ETL,  Big Data Technologies,  Test Automation,  Data Validation'
#  'Database Management,  SQL,  Data Modeling,  Database Administration,  Performance Tuning,  Backup and Recovery,  Database Security'
#  'Data Analysis,  SQL,  Excel,  Data Visualization,  Statistical Analysis,  Python,  R,  Tableau,  Power BI'
#  ' Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Data Strategy'
#  'Database Administration,  SQL,  Data Modeling,  Backup and Recovery,  Performance Tuning,  Database Security,  Troubleshooting'
#  'Cybersecurity,  Network Security,  Security Protocols,  SIEM Tools,  Firewall Management,  Intrusion Detection,  Security Policies'
#  'Business Intelligence,  Data Analysis,  Data Visualization,  SQL,  Business Intelligence Tools,  Reporting,  Dashboard Creation'
#  'Data Testing,  Quality Assurance,  Hadoop,  Spark,  SQL,  ETL,  Big Data Technologies,  Test Automation'
#  'Database Operations,  SQL,  Data Modeling,  Performance Optimization,  Backup and Recovery,  Database Security'
#  'Data Analysis,  SQL,  Data Visualization,  Statistical Analysis,  Python,  R,  Tableau,  Power BI,  Data Interpretation'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  Cloud Computing,  Data Pipeline Development'
#  'Database Security,  SQL,  Security Protocols,  Access Control,  Vulnerability Assessment,  Security Policies,  Encryption'
#  'Cybersecurity,  Network Security,  Security Incident Response,  SIEM Tools,  Firewall Management,  Threat Detection,  Security Policies'
#  'Data Architecture,  Cloud Computing,  Data Warehousing,  SQL,  ETL,  Big Data Technologies,  Data Modeling,  Solution Design'
#  'Hadoop Administration,  Cluster Management,  Scalability,  Performance Optimization,  Cloud Computing,  Linux']
# ----------------------------------------------------------------------------------------------------
# Unique Labels: ['Engineer' 'Scientist' 'Architect' 'Analyst' 'Developer' 'Manager'
#  'Specialist' 'Administrator' 'Consultant' 'Other']

# %%
# # print the competency levels for each skill
for key, value in skill_to_competency.items():
    print(f"\nCompetency levels for skill '{key}':")
    print(tabulate({'Competency': dataset[key].unique()}, headers='keys', tablefmt='pretty'))
# Out:
# Competency levels for skill 'python':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'sql':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'machine learning':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data visualization':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'big data':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'hadoop':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'spark':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'java':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'c++':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'r':
# +--------------+
# |  Competency  |
# +--------------+
# | Intermediate |
# |              |
# +--------------+
#
# Competency levels for skill 'aws':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'azure':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'tableau':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'power bi':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'tensorflow':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'keras':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'scikit learn':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'nlp':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'deep learning':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'neural networks':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'computer vision':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data mining':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data warehousing':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data modeling':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data engineering':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data architecture':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data governance':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data quality':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data analytics':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data science':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data analysis':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data management':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data integration':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data migration':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+
#
# Competency levels for skill 'data strategy':
# +------------+
# | Competency |
# +------------+
# |            |
# +------------+

# %%
for key, value in skill_to_competency.items():
  print(f'Competency levels for skill {key}: is {value}')
# Out:
# Competency levels for skill python: is Advanced
# Competency levels for skill sql: is Intermediate
# Competency levels for skill machine learning: is Intermediate
# Competency levels for skill data visualization: is Intermediate
# Competency levels for skill big data: is Advanced
# Competency levels for skill hadoop: is Advanced
# Competency levels for skill spark: is Advanced
# Competency levels for skill java: is Intermediate
# Competency levels for skill c++: is Intermediate
# Competency levels for skill r: is Intermediate
# Competency levels for skill aws: is Intermediate
# Competency levels for skill azure: is Intermediate
# Competency levels for skill tableau: is Intermediate
# Competency levels for skill power bi: is Intermediate
# Competency levels for skill tensorflow: is Intermediate
# Competency levels for skill keras: is Intermediate
# Competency levels for skill scikit learn: is Intermediate
# Competency levels for skill nlp: is Intermediate
# Competency levels for skill deep learning: is Intermediate
# Competency levels for skill neural networks: is Intermediate
# Competency levels for skill computer vision: is Intermediate
# Competency levels for skill data mining: is Intermediate
# Competency levels for skill data warehousing: is Intermediate
# Competency levels for skill data modeling: is Intermediate
# Competency levels for skill data engineering: is Intermediate
# Competency levels for skill data architecture: is Intermediate
# Competency levels for skill data governance: is Intermediate
# Competency levels for skill data quality: is Intermediate
# Competency levels for skill data analytics: is Intermediate
# Competency levels for skill data science: is Intermediate
# Competency levels for skill data analysis: is Intermediate
# Competency levels for skill data management: is Intermediate
# Competency levels for skill data integration: is Intermediate
# Competency levels for skill data migration: is Intermediate
# Competency levels for skill data strategy: is Intermediate

# %%
# print all the unique skills in the dataset, literally all of them

print('-' * 100)
# Print unique values in the 'Skills Required' column 
print("Unique Skills:", dataset['Skills Required'].unique())
# Out:
# ----------------------------------------------------------------------------------------------------
# Unique Skills: ['Hadoop,  Spark,  SQL,  Python,  ETL,  Big Data,  NoSQL'
#  'Python,  TensorFlow,  PyTorch,  Machine Learning,  Deep Learning,  NLP,  Data Visualization'
#  'Python,  R,  Machine Learning,  Statistical Analysis,  Data Visualization,  SQL,  Big Data'
#  'Hadoop,  Spark,  Data Modeling,  NoSQL,  Cloud Computing,  ETL'
#  'SQL,  Excel,  Data Visualization,  Statistics,  Data Cleaning,  Tableau,  Power BI'
#  'Hadoop,  Spark,  Java,  Python,  Kafka,  Hive,  Pig,  Flume'
#  'Machine Learning,  Deep Learning,  Natural Language Processing,  Reinforcement Learning,  Python,  TensorFlow,  PyTorch'
#  'ETL,  Data Quality,  Data Governance,  SQL,  Leadership,  Data Integration'
#  'SQL,  ETL,  Data Modeling,  Data Warehousing,  Business Intelligence,  Dimensional Modeling'
#  'SQL,  Tableau,  Power BI,  Data Visualization,  Business Analysis,  Data Reporting'
#  'Python,  Machine Learning,  Data Visualization,  Statistical Analysis,  Big Data,  R'
#  'Hadoop,  Spark,  Python,  ETL,  NoSQL,  SQL'
#  'Python,  TensorFlow,  PyTorch,  Deep Learning,  Computer Vision,  Natural Language Processing'
#  'Hadoop,  Spark,  Linux,  HDFS,  Cloudera,  Hortonworks,  AWS'
#  'Machine Learning,  Data Strategy,  Leadership,  Python,  R,  Data Analytics,  Data Visualization'
#  'Hadoop,  Spark,  Scala,  Kafka,  Data Streaming,  NoSQL'
#  'Hadoop,  Spark,  SQL,  NoSQL,  Data Modeling,  Cloud Computing,  ETL'
#  'SQL,  Excel,  Tableau,  Data Visualization,  Data Cleaning,  Data Analysis'
#  'Python,  R,  Machine Learning,  Deep Learning,  Natural Language Processing,  Data Visualization'
#  'Hadoop,  Spark,  Python,  SQL,  Data Visualization,  ETL'
#  'Machine Learning,  Deep Learning,  Python,  TensorFlow,  PyTorch,  NLP'
#  'Data Governance,  Data Quality,  Data Management,  Compliance,  Policy Development'
#  'Hadoop,  Spark,  Data Modeling,  Cloud Computing,  NoSQL,  ETL,  Architecture Design'
#  'Hadoop,  Spark,  Python,  ETL,  Data Warehousing,  SQL'
#  'Python,  TensorFlow,  PyTorch,  Deep Learning,  Leadership,  Project Management'
#  'Python,  R,  Machine Learning,  Statistical Analysis,  Data Visualization,  Big Data'
#  'Hadoop,  Spark,  Project Management,  Agile,  Scrum,  Stakeholder Communication'
#  'SQL,  Excel,  Tableau,  Power BI,  Data Visualization,  Data Cleaning'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  TensorFlow,  Pandas,  Numpy'
#  'SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure,  GCP'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Data Preprocessing,  Model Evaluation'
#  'SQL,  Excel,  Data Visualization,  Statistical Analysis,  Python,  R,  Tableau,  Power BI,  Data Cleaning'
#  'Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  NoSQL,  Cloud Computing,  Big Data Technologies,  Data Governance'
#  'Data Analysis,  Hadoop,  Spark,  Python,  SQL,  Data Visualization,  Data Cleaning,  Statistical Analysis'
#  'Machine Learning,  Deep Learning,  Neural Networks,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis'
#  'Data Strategy,  Team Leadership,  Project Management,  Data Analytics,  Data Visualization,  Machine Learning,  SQL,  Python'
#  'Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  Solution Design,  AWS,  Azure'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Deep Learning'
#  'SQL,  Data Modeling,  ETL,  Data Integration,  Database Design,  Data Warehousing,  SQL Server,  Oracle,  Teradata'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration'
#  'Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  Machine Learning,  SQL,  Data Cleaning'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  Azure,  Data Warehousing,  Python'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Data Preprocessing,  Model Evaluation,  Data Analysis'
#  'Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  HBase,  Kafka,  Linux,  Shell Scripting'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Analysis,  Data Visualization,  SQL,  Deep Learning'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  AWS,  GCP,  Data Warehousing,  Python'
#  'Machine Learning,  Deep Learning,  NLP,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis'
#  'SQL,  ETL,  Python,  Apache Kafka,  Hadoop,  Spark,  Data Warehousing,  NoSQL,  AWS,  Azure'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  Computer Vision,  NLP,  Data Preprocessing'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  SQL'
#  'Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  Azure'
#  'Data Strategy,  Machine Learning,  Data Analytics,  Data Visualization,  SQL,  Python'
#  'Hadoop Administration,  Cluster Management,  Scalability,  Performance Optimization,  Cloud Computing'
#  'MLOps,  Model Deployment,  Docker,  Kubernetes,  Python,  MLflow,  CI/CD,  Monitoring'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  ETL,  Data Modeling,  AWS,  GCP'
#  'Data Analysis,  Data Visualization,  Excel,  Tableau,  SQL,  Python'
#  'Machine Learning Research,  Python,  TensorFlow,  PyTorch,  Research,  Data Analysis,  NLP'
#  'Project Management,  Data Strategy,  Data Analytics,  Team Leadership,  Data Visualization'
#  'Hadoop Security,  Apache Ranger,  Knox,  Kerberos,  Encryption,  Data Access Control'
#  'Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  Cloud Data Warehouses,  Snowflake,  Redshift'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Model Deployment'
#  'Machine Learning,  Python,  R,  Data Analysis,  Statistical Modeling,  Data Visualization,  SQL,  Team Leadership'
#  'Hadoop,  Spark,  Docker,  Kubernetes,  CI/CD,  Jenkins,  Ansible,  Linux,  Scripting,  Infrastructure as Code'
#  'Data Quality Assurance,  Data Validation,  Data Cleansing,  SQL,  Data Profiling,  Data Governance'
#  'MLOps,  Model Deployment,  CI/CD,  Monitoring,  Team Leadership,  Docker,  Kubernetes,  Python'
#  'Data Compliance,  Data Privacy,  GDPR,  CCPA,  Data Governance,  Legal Compliance,  Risk Assessment'
#  'Ethical AI,  Responsible AI,  Fairness,  Bias Mitigation,  Ethical Guidelines,  AI Ethics'
#  'Infrastructure Design,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  Scalability,  High Availability'
#  'Machine Learning,  Data Analysis,  Python,  R,  Teaching,  Curriculum Development,  Data Visualization'
#  'Data Migration,  ETL,  Data Transformation,  Legacy Systems,  AWS,  Azure,  Data Cleansing'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance'
#  'Hadoop,  Spark,  Troubleshooting,  Support,  Linux,  Shell Scripting,  Apache HBase,  Kafka'
#  'Data Strategy,  Machine Learning,  Data Analytics,  Data Visualization,  SQL,  Python,  Client Engagement'
#  'Hadoop Performance,  Spark Performance,  Optimization,  Monitoring,  Troubleshooting,  Benchmarking'
#  'Data Modeling,  Data Warehousing,  Database Design,  SQL,  ETL,  Cloud Data Warehouses,  Snowflake'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Model Deployment,  Research'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Leadership'
#  'Hadoop Administration,  Cloudera,  Hortonworks,  HDFS,  Spark,  Linux,  Shell Scripting,  Cluster Management'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  SQL,  Compliance'
#  'Data Architecture,  Cloud Computing,  Hadoop,  Spark,  NoSQL,  ETL,  Data Modeling,  AWS,  GCP'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration,  Leadership'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Leadership'
#  'Data Migration,  ETL,  Data Transformation,  Legacy Systems,  AWS,  Azure,  Data Cleansing,  Leadership'
#  'SQL,  ETL,  Python,  Hadoop,  Spark,  AWS,  Azure,  Data Warehousing,  NoSQL,  Data Integration,  Strategic Planning'
#  'MLOps,  Model Deployment,  CI/CD,  Monitoring,  Team Leadership,  Docker,  Kubernetes,  Python,  Strategy'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Strategic Planning'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Model Deployment,  Research,  Leadership'
#  'Data Analysis,  Hadoop,  Spark,  Python,  SQL,  Data Visualization,  Data Cleaning,  Statistical Analysis,  Leadership'
#  'Machine Learning,  Python,  TensorFlow,  PyTorch,  Deep Learning,  NLP,  Computer Vision,  Data Preprocessing'
#  'Data Testing,  Quality Assurance,  Hadoop,  Spark,  SQL,  ETL,  Big Data Technologies,  Test Automation,  Data Validation'
#  'Database Management,  SQL,  Data Modeling,  Database Administration,  Performance Tuning,  Backup and Recovery,  Database Security'
#  'Data Analysis,  SQL,  Excel,  Data Visualization,  Statistical Analysis,  Python,  R,  Tableau,  Power BI'
#  ' Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  AWS,  Python,  Hive'
#  'Data Governance,  Data Management,  Data Quality,  Data Policies,  Data Stewardship,  Compliance,  Data Strategy'
#  'Database Administration,  SQL,  Data Modeling,  Backup and Recovery,  Performance Tuning,  Database Security,  Troubleshooting'
#  'Cybersecurity,  Network Security,  Security Protocols,  SIEM Tools,  Firewall Management,  Intrusion Detection,  Security Policies'
#  'Business Intelligence,  Data Analysis,  Data Visualization,  SQL,  Business Intelligence Tools,  Reporting,  Dashboard Creation'
#  'Data Testing,  Quality Assurance,  Hadoop,  Spark,  SQL,  ETL,  Big Data Technologies,  Test Automation'
#  'Database Operations,  SQL,  Data Modeling,  Performance Optimization,  Backup and Recovery,  Database Security'
#  'Data Analysis,  SQL,  Data Visualization,  Statistical Analysis,  Python,  R,  Tableau,  Power BI,  Data Interpretation'
#  'Hadoop,  Spark,  Scala,  Java,  SQL,  NoSQL,  Data Warehousing,  ETL,  Cloud Computing,  Data Pipeline Development'
#  'Database Security,  SQL,  Security Protocols,  Access Control,  Vulnerability Assessment,  Security Policies,  Encryption'
#  'Cybersecurity,  Network Security,  Security Incident Response,  SIEM Tools,  Firewall Management,  Threat Detection,  Security Policies'
#  'Data Architecture,  Cloud Computing,  Data Warehousing,  SQL,  ETL,  Big Data Technologies,  Data Modeling,  Solution Design'
#  'Hadoop Administration,  Cluster Management,  Scalability,  Performance Optimization,  Cloud Computing,  Linux']

# %% [markdown]
# ### Data cleaning

# %%
import pandas as pd
import os

# %%
# Create the 'data/processed' directory if it doesn't exist
processed_data_directory = '../data/processed/'
os.makedirs(processed_data_directory, exist_ok=True)

# %%
input_csv_file = '../data/raw/first_set.csv'
output_csv_file = '../data/raw/revsioned_first_set.csv'

# %%
# import csv

# with open(input_csv_file, 'r', newline='') as input_file, open(output_csv_file, 'w', newline='') as output_file:
#     csv_reader = csv.reader(input_file)
#     csv_writer = csv.writer(output_file)

#     for row in csv_reader:
#         if len(row) >= 2:
#             formatted_row = [row[0], f'"{", ".join(row[1::])}"']
#             csv_writer.writerow(formatted_row)
#         else:
#             csv_writer.writerow(row)

# print(f'CSV file "{output_csv_file}" with formatted values has been created.')

# %%
dataset = '../data/raw/revisioned_first_set.csv'

# %%
df = pd.read_csv(dataset)
df.head()
# Out:
#               Job Role Title  \
# 0              Data Engineer
# 1  Machine Learning Engineer
# 2             Data Scientist
# 3         Big Data Architect
# 4               Data Analyst
#
#                                      Skills Required
# 0  Hadoop,  Spark,  SQL,  Python,  ETL,  Big Data...
# 1  Python,  TensorFlow,  PyTorch,  Machine Learni...
# 2  Python,  R,  Machine Learning,  Statistical An...
# 3  Hadoop,  Spark,  Data Modeling,  NoSQL,  Cloud...
# 4  SQL,  Excel,  Data Visualization,  Statistics,...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Role Title   177 non-null    object
#  1   Skills Required  177 non-null    object
# dtypes: object(2)
# memory usage: 2.9+ KB

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 171 entries, 0 to 176
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Role Title   171 non-null    object
#  1   Skills Required  171 non-null    object
# dtypes: object(2)
# memory usage: 4.0+ KB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Example dataset
job_roles = ["Data Engineer", "Machine Learning Engineer", "Big Data Engineer"]
skills = ["SQL, ETL, Python", "Machine Learning, Python, TensorFlow", "Hadoop, Spark, ETL"]

# Preprocess the dataset
job_skill_dict = {role: skill.split(", ") for role, skill in zip(job_roles, skills)}

# Calculate similarity between job roles
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(job_roles)
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# Set a similarity threshold
similarity_threshold = 0.6

# Group similar job roles
similar_roles = {}
for i, role in enumerate(job_roles):
    similar_roles[role] = [job_roles[j] for j, sim in enumerate(cosine_sim[i]) if i != j and sim >= similarity_threshold]

# Combine skills of similar job roles
combined_skills = {}
for role, similar in similar_roles.items():
    combined_skills[role] = set(job_skill_dict[role])
    for similar_role in similar:
        combined_skills[role].update(job_skill_dict[similar_role])

# Example user input
user_input = "Big Data"

# Find matched job roles
matched_roles = [role for role in job_roles if user_input in role]

if not matched_roles:
    # No exact match, find similar roles
    for role, similar in similar_roles.items():
        if user_input in similar:
            matched_roles.extend([role] + similar)

# Display combined skills for matched roles
if matched_roles:
    for role in matched_roles:
        print(f"Job Role: {role}")
        print(f"Combined Skills: {', '.join(combined_skills[role])}")
else:
    print("No matching job roles found.")
# Out:
# Job Role: Big Data Engineer
# Combined Skills: Python, Hadoop, SQL, Spark, ETL

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

job_roles = ["Data Engineer", "Machine Learning Engineer", "Big Data Engineer"]
skills = ["SQL, ETL, Python", "Machine Learning, Python, TensorFlow", "Hadoop, Spark, ETL"]

job_skill_dict = {role: skill.split(", ") for role, skill in zip(job_roles, skills)}

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(job_roles)
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

similarity_threshold = 0.6

similar_roles = {}
for i, role in enumerate(job_roles):
    similar_roles[role] = [job_roles[j] for j, sim in enumerate(cosine_sim[i]) if i != j and sim >= similarity_threshold]

combined_skills = {}
for role, similar in similar_roles.items():
    combined_skills[role] = set(job_skill_dict[role])
    for similar_role in similar:
        combined_skills[role].update(job_skill_dict[similar_role])

user_input = "Data"

user_tokens = user_input.split()

matched_roles = []

for role in job_roles:
    role_tokens = role.split()
    for token in user_tokens:
        if token in role_tokens:
            matched_roles.append(role)
            break

if matched_roles:
    for role in matched_roles:
        print(f"Job Role: {role}")
        print(f"Combined Skills: {', '.join(combined_skills[role])}")
else:
    print("No matching job roles found.")
# Out:
# Job Role: Data Engineer
# Combined Skills: Python, Hadoop, Spark, SQL, ETL
# Job Role: Big Data Engineer
# Combined Skills: Python, Hadoop, SQL, Spark, ETL

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

job_roles = ["Data Engineer", "Machine Learning Engineer", "Big Data Engineer"]
skills = ["SQL, ETL, Python", "Machine Learning, Python, TensorFlow", "Hadoop, Spark, ETL"]

job_skill_dict = {role: skill.split(", ") for role, skill in zip(job_roles, skills)}

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(job_roles)
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

similarity_threshold = 0.6

similar_roles = {}
for i, role in enumerate(job_roles):
    similar_roles[role] = [job_roles[j] for j, sim in enumerate(cosine_sim[i]) if i != j and sim >= similarity_threshold]

combined_skills = {}
for role, similar in similar_roles.items():
    combined_skills[role] = set(job_skill_dict[role])
    for similar_role in similar:
        combined_skills[role].update(job_skill_dict[similar_role])

user_input = "Data"

user_tokens = user_input.split()

matched_roles = []

for role in job_roles:
    role_tokens = role.split()
    for token in user_tokens:
        if token in role_tokens:
            matched_roles.append(role)
            break

if matched_roles:
    for role in matched_roles:
        print(f"Job Role: {role}")
        print(f"Combined Skills: {', '.join(combined_skills[role])}")
else:
    print("No matching job roles found.")
# Out:
# Job Role: Data Engineer
# Combined Skills: Python, Hadoop, Spark, SQL, ETL
# Job Role: Big Data Engineer
# Combined Skills: Python, Hadoop, SQL, Spark, ETL

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

dataset = pd.read_csv('../data/raw/revisioned_first_set.csv')

job_roles = dataset['Job Role Title'].tolist()
skills = dataset['Skills Required'].tolist()

job_skill_dict = {role: skill.split(", ") for role, skill in zip(job_roles, skills)}

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(job_roles)
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

similarity_threshold = 0.6

similar_roles = {}
for i, role in enumerate(job_roles):
    similar_roles[role] = [job_roles[j] for j, sim in enumerate(cosine_sim[i]) if i != j and sim >= similarity_threshold]

combined_skills = {}
for role, similar in similar_roles.items():
    combined_skills[role] = set(job_skill_dict[role])
    for similar_role in similar:
        combined_skills[role].update(job_skill_dict[similar_role])

user_input = "Data Scientist"

user_tokens = user_input.split()

matched_roles = []

for role in job_roles:
    role_tokens = role.split()
    for token in user_tokens:
        if token in role_tokens:
            matched_roles.append(role)
            break

if matched_roles:
    for role in matched_roles:
        print(f"Job Role: {role}")
        print(f"Combined Skills: {', '.join(combined_skills[role])} \n")
else:
    print("No matching job roles found.")
# Out:
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Scala, Hadoop,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Java,  NoSQL,  Hive, SQL,  SQL,  Azure
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Scalability,  Hadoop, Infrastructure Design,  Data Governance,  Cloud Computing,  Azure,  Database Design,  ETL,  Data Warehousing,  Data Modeling,  SQL, Hadoop,  Big Data Technologies, Data Architecture,  Spark,  AWS, Data Modeling,  NoSQL,  High Availability
#
# Job Role: D
# Combined Skills:  Python,  Statistical Analysis,  Data Quality,  Power BI,  Hadoop,  Spark,  Data Cleaning, Data Governance,  Tableau, SQL, Data Analysis,  SQL,  R,  Data Management,  Excel,  Data Visualization,  Data Policies,  Data Stewardship
#
# Job Role: B
# Combined Skills:  Hadoop,  Java, SQL,  Cloud Computing,  Database Design,  Scala,  ETL,  Data Warehousing,  Data Pipeline Development,  Data Modeling,  SQL,  GCP,  Python,  Oracle, Hadoop,  Hive,  SQL Server,  Teradata,  Data Integration,  Spark,  AWS,  NoSQL
#
# Job Role: A
# Combined Skills:  Python,  Data Analysis,  Neural Networks, Machine Learning,  NLP,  TensorFlow,  PyTorch,  Deep Learning,  Research
#
# Job Role: D
# Combined Skills:  Scalability,  Backup and Recovery,  Performance Optimization,  Data Integration, Hadoop Administration,  Data Quality,  Leadership, Database Operations, ETL,  Data Governance,  SQL,  Data Modeling,  Cloud Computing,  Cluster Management,  Database Security
#
# Job Role: D
# Combined Skills:  Teradata,  Business Intelligence,  Oracle,  Data Integration,  Snowflake,  Redshift,  ETL,  Data Warehousing, Data Modeling,  Cloud Data Warehouses,  Data Modeling, SQL,  SQL,  Database Design,  SQL Server,  Dimensional Modeling
#
# Job Role: S
# Combined Skills: Machine Learning,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Azure,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Excel,  AWS,  Spark,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  TensorFlow,  NLP,  Java, SQL,  Azure,  Scala,  ETL,  Data Warehousing,  PyTorch,  SQL,  Python,  Model Deployment, Hadoop,  Hive,  Computer Vision,  Data Integration,  Spark,  AWS,  NoSQL,  Deep Learning
#
# Job Role: B
# Combined Skills:  Scalability,  HBase,  Performance Optimization,  Cloud Computing,  Shell Scripting, Hadoop Administration,  Linux,  Spark,  Hortonworks,  Kafka,  Cloudera,  Cluster Management,  HDFS
#
# Job Role: D
# Combined Skills:  Team Leadership,  Python,  Data Strategy,  Data Analytics, Data Strategy,  Machine Learning,  Project Management,  SQL,  Data Visualization, Project Management
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  TensorFlow,  NLP,  Java, SQL,  Azure,  Research,  Scala,  ETL,  Data Warehousing,  PyTorch,  SQL,  Python,  Model Deployment, Hadoop,  Hive,  Data Integration,  Spark,  AWS,  NoSQL,  Deep Learning
#
# Job Role: B
# Combined Skills:  Data Strategy, Data Strategy,  Data Quality,  Java,  Azure,  Data Analytics,  Scala,  Client Engagement,  ETL,  Data Warehousing,  SQL,  Python,  Machine Learning, Hadoop, Data Governance,  Data Policies,  Data Stewardship,  Spark,  AWS,  Compliance,  NoSQL,  Data Management,  Data Visualization
#
# Job Role: S
# Combined Skills: Machine Learning,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Azure,  Data Analysis,  Statistical Modeling,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Excel,  Spark,  AWS,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Hadoop,  Data Cleaning,  Tableau, SQL,  R,  Spark Performance,  Optimization,  Statistical Analysis,  Leadership,  ETL,  Troubleshooting,  SQL,  Benchmarking,  Python,  Power BI, Hadoop Performance,  Big Data Technologies, Data Analysis,  Excel, Data Testing,  Spark,  Monitoring,  Test Automation,  Quality Assurance,  Data Visualization
#
# Job Role: D
# Combined Skills:  Data Strategy,  Data Quality,  Compliance, Data Governance,  SQL,  Data Management,  Data Policies,  Data Stewardship
#
# Job Role: B
# Combined Skills:  Hadoop,  Java,  Data Governance,  Cloud Computing,  Azure,  Database Design,  Scala,  ETL,  Data Warehousing,  Data Pipeline Development,  Data Modeling,  SQL,  GCP,  Python, Hadoop,  Big Data Technologies, Data Architecture,  Spark,  AWS, Data Modeling,  NoSQL
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  Data Cleaning,  TensorFlow,  NLP, SQL,  Data Governance,  R,  Cloud Computing,  Azure,  Database Design,  Research,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  Leadership,  ETL,  Apache Kafka,  Data Warehousing,  PyTorch,  SQL,  Python,  Model Deployment,  Big Data Technologies, Data Analysis,  Spark,  AWS, Data Modeling,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Team Leadership,  Data Strategy,  Data Visualization,  Data Analytics, Hadoop,  Spark,  Project Management,  Stakeholder Communication,  Scrum,  Agile, Project Management
#
# Job Role: D
# Combined Skills:  Data Quality,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Statistical Analysis,  SQL,  Python,  Power BI, Data Governance, Data Analysis,  Excel,  Data Policies,  Data Stewardship,  Spark,  Compliance,  Data Management,  Data Visualization
#
# Job Role: B
# Combined Skills:  Python,  Data Integration,  Scala, Hadoop,  Spark,  AWS,  ETL,  Data Warehousing,  Java,  Hive,  NoSQL,  Hadoop, SQL,  SQL,  Azure,  GCP
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Scala, Hadoop,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Java,  NoSQL,  Hive, SQL,  SQL,  Azure
#
# Job Role: D
# Combined Skills:  Python,  Statistical Analysis,  Data Quality,  Power BI,  Hadoop,  Spark,  Data Cleaning, Data Governance,  Tableau, SQL, Data Analysis,  SQL,  R,  Data Management,  Excel,  Data Visualization,  Data Policies,  Data Stewardship
#
# Job Role: D
# Combined Skills:  Hadoop,  Data Governance,  Cloud Computing,  Azure,  Database Design,  ETL,  Data Warehousing,  Data Modeling,  SQL, Hadoop,  Big Data Technologies,  Cloud Data Warehouses,  Redshift,  Snowflake, Data Architecture,  Spark,  AWS, Data Modeling,  NoSQL
#
# Job Role: B
# Combined Skills:  Hadoop,  Data Cleaning,  Tableau, SQL,  R,  Spark Performance,  Optimization,  Statistical Analysis,  Leadership,  ETL,  Troubleshooting,  SQL,  Benchmarking,  Python,  Power BI, Hadoop Performance,  Big Data Technologies, Data Analysis,  Excel, Data Testing,  Spark,  Monitoring,  Test Automation,  Quality Assurance,  Data Visualization
#
# Job Role: A
# Combined Skills:  Python,  Data Analysis,  Neural Networks, Machine Learning,  NLP,  TensorFlow,  PyTorch,  Deep Learning,  Research
#
# Job Role: D
# Combined Skills:  Team Leadership,  Python,  Data Strategy,  Data Analytics, Data Strategy,  Machine Learning,  Project Management,  SQL,  Data Visualization, Project Management
#
# Job Role: B
# Combined Skills:  Hadoop,  Java,  Data Governance,  Cloud Computing,  Azure,  Database Design,  Scala,  ETL,  Data Warehousing,  Data Pipeline Development,  Data Modeling,  SQL,  GCP,  Python, Hadoop,  Big Data Technologies, Data Architecture,  Spark,  AWS, Data Modeling,  NoSQL
#
# Job Role: S
# Combined Skills: Machine Learning,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Azure,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Excel,  AWS,  Spark,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Hadoop,  Java, SQL,  Database Design,  Business Intelligence,  Scala,  ETL,  Data Warehousing,  Data Modeling,  SQL,  Python,  Oracle,  Hive,  SQL Server,  Teradata,  Dimensional Modeling,  Data Integration,  Spark,  AWS,  NoSQL
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  TensorFlow,  NLP,  Java, SQL,  Azure,  Scala,  ETL,  Data Warehousing,  PyTorch,  SQL,  Python,  Model Deployment, Hadoop,  Hive,  Computer Vision,  Data Integration,  Spark,  AWS,  NoSQL,  Deep Learning
#
# Job Role: D
# Combined Skills:  Data Analysis, Python,  Machine Learning,  Statistical Analysis,  Data Cleaning,  R,  SQL,  Data Visualization
#
# Job Role: B
# Combined Skills:  Data Strategy, Data Strategy,  Data Quality,  Java,  Azure,  Data Analytics,  Scala,  Client Engagement,  ETL,  Data Warehousing,  SQL,  Python,  Machine Learning, Hadoop, Data Governance,  Data Policies,  Data Stewardship,  Spark,  AWS,  Compliance,  NoSQL,  Data Management,  Data Visualization
#
# Job Role: J
# Combined Skills:  Python,  Statistical Analysis,  Power BI,  Data Cleaning,  Tableau, SQL,  R,  Excel,  Data Visualization
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  TensorFlow,  NLP,  Java, SQL,  Azure,  Research,  Scala,  ETL,  Data Warehousing,  PyTorch,  SQL,  Python,  Model Deployment, Hadoop,  Hive,  Data Integration,  Spark,  AWS,  NoSQL,  Deep Learning
#
# Job Role: L
# Combined Skills:  Team Leadership, Machine Learning,  Hadoop, SQL,  R,  Azure,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  ETL,  Data Warehousing,  SQL,  Python,  Data Integration,  Spark,  AWS,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Scalability,  HBase,  Performance Optimization,  Cloud Computing,  Shell Scripting, Hadoop Administration,  Linux,  Spark,  Hortonworks,  Kafka,  Cloudera,  Cluster Management,  HDFS
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Scala, Hadoop,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Java,  NoSQL,  Hive, SQL,  SQL,  Azure
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Python, Data Architecture,  Scala, Hadoop,  Spark,  AWS,  ETL,  Data Warehousing,  Java,  Hadoop,  NoSQL,  Hive,  Data Modeling,  Data Pipeline Development,  SQL,  Cloud Computing,  Azure,  GCP
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Neural Networks, Machine Learning,  NLP,  TensorFlow,  PyTorch,  Deep Learning,  Research
#
# Job Role: S
# Combined Skills: Machine Learning,  Hadoop,  Data Cleaning,  Tableau, SQL,  R,  Azure,  Data Analysis,  Statistical Modeling,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Excel,  Spark,  AWS,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Strategy,  Data Quality,  Statistical Analysis,  Power BI,  Compliance, Data Governance,  Tableau, Data Analysis,  SQL,  R,  Data Management,  Excel,  Data Visualization,  Data Policies,  Data Stewardship
#
# Job Role: B
# Combined Skills:  Hadoop,  Java,  Data Governance,  Cloud Computing,  Azure,  Database Design,  Scala,  ETL,  Data Warehousing,  Data Pipeline Development,  Data Modeling,  SQL,  GCP,  Python, Hadoop,  Big Data Technologies, Data Architecture,  Spark,  AWS, Data Modeling,  NoSQL
#
# Job Role: D
# Combined Skills:  Python,  Data Analytics, Data Strategy,  Machine Learning,  Scala, Hadoop,  Spark,  AWS,  ETL,  Data Warehousing,  Java,  Client Engagement,  NoSQL,  SQL,  Azure,  Data Visualization
#
# Job Role: B
# Combined Skills:  Scalability,  Backup and Recovery,  Performance Optimization,  Data Integration, Hadoop Administration,  Data Quality,  Leadership, Database Operations, ETL,  Data Governance,  SQL,  Data Modeling,  Cloud Computing,  Cluster Management,  Database Security
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Data Analysis,  Statistical Modeling, Machine Learning,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Leadership,  NoSQL, SQL,  R,  SQL,  Azure,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Scalability,  Hadoop,  Java,  Cloud Computing,  Scala,  ETL,  Data Warehousing,  Data Modeling,  SQL,  Cluster Management,  GCP,  Python,  Performance Optimization,  Linux, Hadoop,  Hive, Hadoop Administration,  Spark,  AWS,  NoSQL
#
# Job Role: D
# Combined Skills:  Python,  Tableau, Data Analysis,  SQL,  Excel,  Data Visualization
#
# Job Role: M
# Combined Skills:  Python,  Data Analysis,  TensorFlow, Machine Learning Research,  NLP,  PyTorch,  Research
#
# Job Role: D
# Combined Skills:  Team Leadership,  Python,  Data Strategy,  Data Analytics, Data Strategy,  Machine Learning, Hadoop,  Spark,  Agile,  Project Management,  Stakeholder Communication,  SQL,  Scrum,  Data Visualization, Project Management
#
# Job Role: B
# Combined Skills:  Data Access Control,  Knox,  Kerberos, Hadoop Security,  Apache Ranger,  Encryption
#
# Job Role: D
# Combined Skills:  Business Intelligence,  Redshift,  Snowflake,  ETL, Data Modeling,  Data Warehousing,  Big Data Technologies,  NoSQL,  Cloud Data Warehouses, SQL,  Data Modeling,  SQL,  Data Governance,  Cloud Computing,  Database Design,  Dimensional Modeling
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  NoSQL, SQL,  Azure
#
# Job Role: B
# Combined Skills:  Data Quality,  Hadoop,  Data Cleaning,  Java,  Tableau, SQL,  R,  Spark Performance,  Optimization,  Scala,  Statistical Analysis,  ETL,  Data Warehousing,  Troubleshooting,  SQL,  Benchmarking,  Python, Hadoop,  Power BI, Hadoop Performance, Data Governance,  Hive, Data Analysis,  Excel,  Data Policies,  Data Stewardship,  Spark,  AWS,  Compliance,  NoSQL,  Monitoring,  Data Management,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Team Leadership,  Data Analysis,  Statistical Modeling, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Docker,  Ansible,  Linux, Hadoop,  Spark,  Scripting,  Infrastructure as Code,  CI/CD,  Kubernetes,  Jenkins
#
# Job Role: D
# Combined Skills:  Data Profiling,  Quality Assurance,  Hadoop,  Spark,  ETL,  Big Data Technologies,  Test Automation,  Data Governance,  SQL, Data Quality Assurance,  Data Validation, Data Testing,  Data Cleansing
#
# Job Role: B
# Combined Skills:  CCPA, Data Compliance,  GDPR,  Data Governance,  Risk Assessment,  Data Privacy,  Legal Compliance
#
# Job Role: D
# Combined Skills: Ethical AI,  Fairness,  Responsible AI,  Ethical Guidelines,  AI Ethics,  Bias Mitigation
#
# Job Role: B
# Combined Skills:  Scalability,  Solution Design, Data Architecture,  High Availability, Hadoop,  Spark,  Hadoop, Infrastructure Design,  ETL,  Data Warehousing,  Big Data Technologies,  NoSQL,  Data Modeling,  SQL,  Cloud Computing
#
# Job Role: D
# Combined Skills:  Curriculum Development,  Python,  Data Analysis,  Teaching, Machine Learning,  R,  Data Visualization
#
# Job Role: B
# Combined Skills:  Data Transformation,  AWS,  Leadership,  ETL, Data Migration,  Azure,  Legacy Systems,  Data Cleansing
#
# Job Role: D
# Combined Skills:  Data Quality,  Leadership,  Compliance, Data Governance,  SQL,  Data Management,  Data Policies,  Data Stewardship
#
# Job Role: B
# Combined Skills:  Shell Scripting,  Linux, Hadoop,  Spark,  Apache HBase,  Troubleshooting,  Kafka,  Support
#
# Job Role: D
# Combined Skills:  Python,  Data Analytics, Data Strategy,  Machine Learning,  Scala,  Client Engagement, Hadoop,  Spark,  ETL,  AWS,  Java,  Data Warehousing,  NoSQL,  SQL,  Azure,  Data Visualization
#
# Job Role: B
# Combined Skills:  Python,  Spark Performance,  Optimization,  Statistical Analysis,  Hadoop, Hadoop Performance,  Spark,  Data Cleaning,  Troubleshooting,  Monitoring, Data Analysis,  SQL,  Data Visualization,  Benchmarking
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Data Analysis,  Statistical Modeling, Machine Learning,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Leadership,  NoSQL, SQL,  R,  SQL,  Azure,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Data Access Control,  Knox,  Kerberos, Hadoop Security,  Apache Ranger,  Encryption
#
# Job Role: D
# Combined Skills:  Teradata,  Business Intelligence,  Oracle,  Redshift,  Snowflake,  Data Integration,  ETL, Data Modeling,  Data Warehousing,  Cloud Data Warehouses, SQL,  Data Modeling,  SQL,  Database Design,  SQL Server,  Dimensional Modeling
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Data Analysis, Python,  Machine Learning,  Statistical Analysis,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Data Cleaning,  NoSQL, SQL,  R,  SQL,  Azure,  Data Visualization
#
# Job Role: B
# Combined Skills:  Hadoop,  Data Cleaning,  Java,  Tableau, SQL,  R,  Scala,  Statistical Analysis,  ETL,  Data Warehousing,  SQL,  Python, Hadoop,  Power BI,  Hive, Data Analysis,  Excel,  AWS,  Spark,  NoSQL,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Leadership,  NoSQL, SQL,  Azure
#
# Job Role: B
# Combined Skills:  Scalability,  Java,  Hortonworks,  Kafka,  Cloud Computing,  HBase,  Shell Scripting,  Scala,  ETL,  Data Modeling,  SQL,  Cluster Management,  GCP,  Performance Optimization,  Linux, Hadoop,  Cloudera, Hadoop Administration,  Spark,  AWS,  NoSQL,  HDFS
#
# Job Role: D
# Combined Skills:  Data Quality,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Statistical Analysis,  Leadership,  SQL,  Python,  Power BI, Data Governance, Data Analysis,  Excel,  Data Policies,  Data Stewardship,  Spark,  Compliance,  Data Management,  Data Visualization
#
# Job Role: B
# Combined Skills:  Python, Data Architecture,  Scala, Hadoop,  Spark,  Hadoop,  ETL,  AWS,  Java,  Data Warehousing,  NoSQL,  Data Modeling,  SQL,  Cloud Computing,  Azure,  GCP
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Neural Networks, Machine Learning,  NLP,  TensorFlow,  PyTorch,  Deep Learning,  Research
#
# Job Role: B
# Combined Skills:  Scalability,  Backup and Recovery,  Performance Optimization,  Data Integration, Hadoop Administration,  Data Quality,  Leadership, Database Operations, ETL,  Data Governance,  SQL,  Data Modeling,  Cloud Computing,  Cluster Management,  Database Security
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Leadership,  NoSQL, SQL,  Azure
#
# Job Role: D
# Combined Skills:  Data Quality,  Leadership,  Compliance, Data Governance,  SQL,  Data Management,  Data Policies,  Data Stewardship
#
# Job Role: B
# Combined Skills:  Scalability,  Solution Design, Data Architecture,  High Availability, Hadoop,  Spark,  Hadoop, Infrastructure Design,  ETL,  Data Warehousing,  Big Data Technologies,  NoSQL,  Data Modeling,  SQL,  Cloud Computing
#
# Job Role: D
# Combined Skills:  Curriculum Development,  Python,  Data Analysis,  Teaching, Machine Learning,  R,  Data Visualization
#
# Job Role: B
# Combined Skills:  Data Transformation,  AWS,  Leadership,  ETL, Data Migration,  Azure,  Legacy Systems,  Data Cleansing
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Strategic Planning,  Data Quality,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing, Data Governance,  NoSQL,  Compliance, SQL,  Data Management,  Azure,  Data Policies,  Data Stewardship
#
# Job Role: D
# Combined Skills:  Python,  Strategic Planning,  Data Integration,  Data Quality,  Hadoop,  Spark,  Compliance,  ETL, Data Governance,  AWS,  Data Warehousing,  NoSQL, SQL,  Data Management,  Azure,  Data Policies,  Data Stewardship
#
# Job Role: B
# Combined Skills:  Python,  Spark Performance,  Optimization,  Statistical Analysis,  Hadoop, Hadoop Performance,  Spark,  Data Cleaning,  Troubleshooting,  Monitoring, Data Analysis,  SQL,  Data Visualization,  Benchmarking
#
# Job Role: D
# Combined Skills:  Teradata,  Oracle,  Redshift,  Snowflake,  Data Integration,  ETL, Data Modeling,  Data Warehousing,  Big Data Technologies,  NoSQL,  Cloud Data Warehouses, SQL,  Data Governance,  SQL,  Data Modeling,  Cloud Computing,  Database Design,  SQL Server
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Data Analysis, Python,  Machine Learning,  Statistical Analysis,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Data Cleaning,  NoSQL, SQL,  R,  SQL,  Azure,  Data Visualization
#
# Job Role: B
# Combined Skills: Machine Learning,  Hadoop,  Data Cleaning, SQL,  Data Governance,  R,  Cloud Computing,  Azure,  Database Design,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  Leadership,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Big Data Technologies, Data Analysis,  AWS,  Spark, Data Modeling,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Hadoop,  Data Cleaning,  Java, SQL,  Azure,  Scala,  Statistical Analysis,  ETL,  Data Warehousing,  SQL,  Python, Hadoop,  Hive, Data Analysis,  Data Integration,  Spark,  AWS,  NoSQL,  Data Visualization
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  Data Cleaning,  TensorFlow,  NLP, SQL,  Data Governance,  R,  Cloud Computing,  Azure,  Database Design,  Research,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  Leadership,  ETL,  Apache Kafka,  Data Warehousing,  PyTorch,  SQL,  Python,  Model Deployment,  Big Data Technologies, Data Analysis,  Spark,  AWS, Data Modeling,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Data Quality,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Statistical Analysis,  SQL,  Python,  Power BI, Data Governance, Data Analysis,  Excel,  Data Policies,  Data Stewardship,  Spark,  Compliance,  Data Management,  Data Visualization
#
# Job Role: D
# Combined Skills:  Hadoop,  Data Governance,  Cloud Computing,  Azure,  Database Design,  ETL,  Data Warehousing,  Data Modeling,  SQL, Hadoop,  Big Data Technologies,  Cloud Data Warehouses,  Redshift,  Snowflake, Data Architecture,  AWS,  Spark, Data Modeling,  NoSQL
#
# Job Role: B
# Combined Skills:  Data Quality,  Hadoop,  Data Cleaning,  Java,  Tableau, SQL,  R,  Spark Performance,  Optimization,  Scala,  Statistical Analysis,  ETL,  Data Warehousing,  Troubleshooting,  SQL,  Benchmarking,  Python, Hadoop,  Power BI, Hadoop Performance, Data Governance,  Hive, Data Analysis,  Excel,  Data Policies,  Data Stewardship,  Spark,  AWS,  Compliance,  NoSQL,  Monitoring,  Data Management,  Data Visualization
#
# Job Role: A
# Combined Skills:  Python,  Data Analysis,  Neural Networks, Machine Learning,  NLP,  TensorFlow,  PyTorch,  Deep Learning,  Research
#
# Job Role: D
# Combined Skills:  Team Leadership,  Python,  Data Strategy,  Data Analytics, Data Strategy,  Machine Learning,  Project Management,  SQL,  Data Visualization, Project Management
#
# Job Role: B
# Combined Skills:  Python, Data Architecture,  Scala, Hadoop,  Spark,  Hadoop,  ETL,  AWS,  Java,  Data Warehousing,  NoSQL,  Data Modeling,  SQL,  Cloud Computing,  Azure,  GCP
#
# Job Role: S
# Combined Skills: Machine Learning,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Azure,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Excel,  Spark,  AWS,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Teradata,  Oracle,  Data Integration,  Snowflake,  ETL,  Data Warehousing, Data Modeling,  Cloud Data Warehouses,  Data Modeling, SQL,  SQL,  Database Design,  SQL Server
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Scala, Hadoop,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  Java,  NoSQL,  Hive, SQL,  SQL,  Azure
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Data Integration, Python,  Machine Learning,  Statistical Analysis,  Data Cleaning,  Hadoop,  ETL,  Spark,  AWS,  Data Warehousing,  NoSQL, SQL,  R,  SQL,  Azure,  Data Visualization
#
# Job Role: B
# Combined Skills:  Python,  Machine Learning,  Scala, Data Strategy,  Data Analytics, Hadoop,  Spark,  AWS,  ETL,  Data Warehousing,  Java,  Client Engagement,  NoSQL,  SQL,  Azure,  Data Visualization
#
# Job Role: J
# Combined Skills:  Python,  Statistical Analysis,  Power BI,  Data Cleaning,  Tableau, SQL,  R,  Excel,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Integration, Machine Learning,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  TensorFlow,  NoSQL,  NLP, SQL,  PyTorch,  Computer Vision,  Data Preprocessing,  Azure,  Deep Learning
#
# Job Role: L
# Combined Skills:  Python,  Data Analysis,  Data Integration,  Statistical Modeling,  Statistical Analysis, Machine Learning,  Hadoop,  Spark,  ETL,  AWS,  Data Warehousing,  NoSQL, SQL,  R,  SQL,  Azure,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Scalability,  HBase,  Performance Optimization,  Cloud Computing,  Shell Scripting, Hadoop Administration,  Linux,  Spark,  Hortonworks,  Kafka,  Cloudera,  Cluster Management,  HDFS
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  Data Cleaning, SQL,  Data Governance,  R,  Cloud Computing,  Azure,  Database Design,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  Leadership,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Big Data Technologies, Data Analysis,  Spark,  AWS, Data Modeling,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Hadoop,  Data Cleaning,  Java, SQL,  Azure,  Scala,  Statistical Analysis,  ETL,  Data Warehousing,  SQL,  Python, Hadoop,  Hive, Data Analysis,  Data Integration,  Spark,  AWS,  NoSQL,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Hadoop,  Spark,  ETL,  Apache Kafka,  Data Warehousing,  AWS,  NoSQL, SQL,  Azure
#
# Job Role: D
# Combined Skills:  Python,  Statistical Analysis,  Power BI,  Data Cleaning,  Hadoop,  Spark,  Tableau, SQL, Data Analysis,  R,  SQL,  Excel,  Data Visualization
#
# Job Role: D
# Combined Skills: Machine Learning,  Hadoop,  Data Cleaning, SQL,  Data Governance,  R,  Cloud Computing,  Azure,  Database Design,  Data Analysis,  Statistical Modeling,  Statistical Analysis,  Leadership,  ETL,  Data Warehousing,  Apache Kafka,  SQL,  Python,  Big Data Technologies, Data Analysis,  AWS,  Spark, Data Modeling,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Hadoop,  Data Cleaning,  Java,  Tableau, SQL,  R,  Scala,  Statistical Analysis,  ETL,  Data Warehousing,  SQL,  Python, Hadoop,  Power BI,  Hive, Data Analysis,  Excel,  AWS,  Spark,  NoSQL,  Data Visualization
#
# Job Role: A
# Combined Skills:  Python,  Data Analysis,  Neural Networks, Machine Learning,  NLP,  TensorFlow,  PyTorch,  Deep Learning,  Research
#
# Job Role: D
# Combined Skills:  Team Leadership,  Python,  Data Analysis,  Data Analytics, Data Strategy,  Machine Learning, Python,  Statistical Analysis,  Data Cleaning,  Project Management,  SQL,  R,  Data Visualization
#
# Job Role: B
# Combined Skills:  Hadoop,  Java,  Data Governance,  Cloud Computing,  Azure,  Database Design,  Scala,  ETL,  Data Warehousing,  Data Modeling,  SQL,  GCP,  Python, Hadoop,  Big Data Technologies, Data Architecture,  Spark,  AWS, Data Modeling,  NoSQL
#
# Job Role: S
# Combined Skills: Machine Learning,  Data Cleaning,  Hadoop,  Tableau, SQL,  R,  Azure,  Data Analysis,  Statistical Modeling,  ETL,  Apache Kafka,  Data Warehousing,  SQL,  Python,  Excel,  AWS,  Spark,  NoSQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Teradata,  Oracle,  Data Integration,  Snowflake,  Redshift,  ETL,  Data Warehousing, Data Modeling,  Cloud Data Warehouses,  Data Modeling, SQL,  SQL,  Database Design,  SQL Server
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  NoSQL, SQL,  Azure
#
# Job Role: D
# Combined Skills:  Team Leadership, Data Strategy, Machine Learning,  Data Cleaning,  Hadoop,  TensorFlow, SQL,  R,  Azure,  Data Analysis,  Data Analytics,  Statistical Analysis,  ETL,  Data Warehousing,  PyTorch,  SQL,  Model Evaluation,  Python, Python,  Machine Learning,  Data Preprocessing,  Data Integration,  Spark,  AWS,  Project Management,  NoSQL,  Data Visualization
#
# Job Role: B
# Combined Skills:  Python,  Scala, Hadoop,  Spark,  AWS,  ETL,  Data Warehousing,  Java,  NoSQL,  SQL,  Azure
#
# Job Role: J
# Combined Skills:  Python,  Statistical Analysis,  Power BI,  Data Cleaning,  Tableau, SQL,  R,  Excel,  Data Visualization
#
# Job Role: D
# Combined Skills:  Python,  Data Integration,  Spark,  Hadoop,  ETL,  AWS,  Data Warehousing,  NoSQL, SQL,  Azure
#
# Job Role: L
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  HBase,  Shell Scripting, Hadoop Administration,  Linux,  Spark,  Hortonworks,  Kafka,  Cloudera,  HDFS
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: B
# Combined Skills:  Spark,  Hadoop,  ETL,  Big Data Technologies,  Test Automation,  SQL,  Quality Assurance, Data Testing,  Data Validation
#
# Job Role: D
# Combined Skills:  Python,  Statistical Analysis,  Data Quality,  Power BI,  Hadoop,  Spark,  Data Cleaning, Data Governance,  Tableau, SQL, Data Analysis,  SQL,  R,  Data Management,  Excel,  Data Visualization,  Data Policies,  Data Stewardship
#
# Job Role: B
# Combined Skills:  Hadoop,  Java, SQL,  Cloud Computing,  Database Design,  Scala,  ETL,  Data Warehousing,  Data Pipeline Development,  Data Modeling,  SQL,  GCP,  Python,  Oracle, Hadoop,  Hive,  SQL Server,  Teradata,  Data Integration,  Spark,  AWS,  NoSQL
#
# Job Role: D
# Combined Skills:  Python,  Data Strategy,  Scala,  Data Quality, Hadoop,  Spark,  AWS,  Compliance,  ETL, Data Governance,  Java,  NoSQL,  Data Warehousing,  SQL,  Data Management,  Azure,  Data Policies,  Data Stewardship
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Statistical Modeling,  Statistical Analysis, Machine Learning,  R,  SQL,  Deep Learning,  Data Visualization
#
# Job Role: D
# Combined Skills:  Hadoop,  Data Governance,  Cloud Computing,  Azure,  Database Design,  ETL,  Data Warehousing,  Data Modeling,  SQL, Hadoop,  Big Data Technologies,  Cloud Data Warehouses,  Redshift,  Snowflake, Data Architecture,  Spark,  AWS, Data Modeling,  NoSQL
#
# Job Role: B
# Combined Skills:  Python,  Data Integration,  Scala, Hadoop,  Spark,  AWS,  ETL,  Data Warehousing,  Java,  Hive,  NoSQL,  Hadoop, SQL,  SQL,  Azure,  GCP
#
# Job Role: B
# Combined Skills:  Python,  Data Visualization,  Data Profiling,  Statistical Analysis,  Spark,  Hadoop,  ETL,  Data Cleaning,  Big Data Technologies,  Test Automation, Data Analysis,  SQL,  Data Governance, Data Quality Assurance,  Quality Assurance, Data Testing,  Data Validation,  Data Cleansing
#
# Job Role: D
# Combined Skills:  Python,  Statistical Analysis,  Power BI,  Tableau,  Data Interpretation, Data Analysis,  SQL,  R,  Data Visualization
#
# Job Role: B
# Combined Skills:  Python, Data Architecture,  Scala, Hadoop,  Spark,  Hadoop,  ETL,  Data Warehousing,  Java,  Data Pipeline Development,  NoSQL,  AWS,  Hive,  Data Modeling,  SQL,  Cloud Computing,  Azure,  GCP
#
# Job Role: D
# Combined Skills:  Data Strategy,  Data Quality,  Compliance, Data Governance,  SQL,  Data Management,  Data Policies,  Data Stewardship
#
# Job Role: D
# Combined Skills:  Python,  Data Analysis,  Neural Networks, Machine Learning,  NLP,  TensorFlow,  PyTorch,  Deep Learning,  Research
#
# Job Role: D
# Combined Skills:  Solution Design,  Scalability, Data Architecture,  High Availability,  Hadoop, Infrastructure Design,  ETL,  Data Warehousing,  Spark,  Big Data Technologies,  NoSQL,  Data Modeling,  SQL,  Cloud Computing
#
# Job Role: B
# Combined Skills:  Scalability,  Java,  Hortonworks,  Kafka,  Cloud Computing,  HBase,  Shell Scripting,  Scala,  ETL,  Data Modeling,  SQL,  Cluster Management,  GCP,  Performance Optimization,  Linux, Hadoop,  Cloudera, Hadoop Administration,  Spark,  AWS,  NoSQL,  HDFS

# %% [markdown]
# In the above code, we used several concepts and libraries for the task of finding job roles based on user input and then displaying the combined skills for those roles. Here are the key concepts and libraries used:
#
# 1. **Pandas:** We used the Pandas library to load and manipulate the dataset stored in a CSV file. Pandas provides data structures and functions for data analysis and manipulation, making it easy to work with tabular data.
#
# 2. **NLP (Natural Language Processing):** NLP concepts are used for tokenizing and processing text data. In particular, we tokenized the job roles, user input, and skills to work with text-based information.
#
# 3. **TF-IDF (Term Frequency-Inverse Document Frequency):** We used TF-IDF vectorization to represent the job roles as numerical vectors. This technique is commonly used in text mining and information retrieval to convert text data into a numerical format for similarity calculations.
#
# 4. **Cosine Similarity:** Cosine similarity is a metric used to determine how similar two vectors (in our case, job roles) are in a high-dimensional space. We calculated the cosine similarity between job roles to identify similar job roles based on their textual content.
#
# 5. **Data Preprocessing:** We preprocessed the dataset by splitting the skills in each job role into a list. This allowed us to work with individual skills for each role.
#
# 6. **Matching and Filtering:** We matched user input against job roles based on common words or tokens. If at least one word from the user input matched with any word in a job role, we considered it a match.
#
# 7. **Thresholding:** We applied a similarity threshold to filter out job roles that are considered similar based on the cosine similarity scores.
#
# 8. **Data Structures:** We used Python dictionaries and sets to organize and store information. Dictionaries were used to map job roles to their corresponding skills, and sets were used to combine and store unique skills.
#
# 9. **Looping and Iteration:** We used loops to iterate through job roles and their similarities, as well as to iterate through tokens in the user input.
#
# 10. **Conditional Statements:** We used conditional statements to filter and display the results, such as showing the combined skills for matched job roles.
#
# These concepts and libraries were combined to create a program that takes user input, finds matching job roles, identifies similar roles, and displays the combined skills for those roles.
